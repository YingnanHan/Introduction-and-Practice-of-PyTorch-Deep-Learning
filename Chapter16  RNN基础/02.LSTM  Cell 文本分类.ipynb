# %%
import torch
import torchtext
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from   torchtext.vocab import GloVe
from   torchtext.legacy.data import Field
from   torch.optim import lr_scheduler

# %%
'''
    LSTM cell 的输入输出格式如下：
    h1,c2 = nn.LSTMCell(input,(h0,c0))
    LSTM是RNN实际应用的标准，其内部结构如下:
'''
nn.LSTM??

# %% [markdown]
# ##### 创建数据集

# %%
TEXT                 = torchtext.legacy.data.Field(lower=True,fix_length=200,batch_first=False)
LABEL                = torchtext.legacy.data.Field(sequential=False)
train,test           = torchtext.legacy.datasets.IMDB.splits(TEXT,LABEL)
TEXT.build_vocab(train,max_size=10000,min_freq=10,vectors=None)
LABEL.build_vocab(train)
train_iter,test_iter = torchtext.legacy.data.BucketIterator.splits((train,test),batch_size=256)

# %% [markdown]
# ##### 创建模型

# %%
embedding_dim = 100
hidden_size   = 300

# %%
class RNN_Encoder(nn.Module):
    '''模型将对评论依次进行读取并输出最后状态'''
    def __init__(self,input_dim,hidden_size):
        '''
            input_dim   表示输入序列的长度
            hidden_size 输出的中间隐藏层的状态数
        '''
        super(RNN_Encoder,self).__init__()
        ''' 初始化RnnCell '''
        self.rnn = nn.LSTMCell(input_dim,hidden_size)
        
    def forward(self,inputs):
        ''' inputs  输入(文本/数值 etc)的序列                     '''
        '''         shape:seq(序列本身),batch(所属batch的大小)    '''
        '''              :embedding(每一个单词所映射到的张量的长度) '''
        bz = inputs.shape[1]  # bz==batch_size
        ''' 初始状态值 每一个单词到达一个层的时候都会产生一个状态       '''
        ht = torch.zeros((bz, hidden_size)).cuda()
        ct = torch.zeros((bz, hidden_size)).cuda()
        for word in inputs:
            '''RNN的输入是Embedding层的输出'''
            ht,ct = self.rnn(word, (ht, ct))
        '''ht是RNN对句子整体理解数值化表示'''
        return ht,ct

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        '''对单词进行Embedding操作参数为词表中单词数目，目标向量空间维度'''
        self.em  = nn.Embedding(len(TEXT.vocab.stoi),embedding_dim)
        '''hidden_size是一个超参数可以自定义'''
        self.rnn = RNN_Encoder(embedding_dim,hidden_size)
        self.fc1 = nn.Linear(hidden_size,256)
        self.fc2 = nn.Linear(256,3)#三分类模型
    
    def forward(self,x):
        x   = self.em(x)  # 词嵌入表示
        _,x = self.rnn(x) # 使用ct作为最终RNN处理序列数据的结果
        x   = self.fc1(x)
        x   = F.relu(x)
        x   = self.fc2(x)
        return x

# %%
model      = Net() 
if torch.cuda.is_available():
    model.to('cuda')
loss_fn    = nn.CrossEntropyLoss()
optimizer  = torch.optim.Adam(model.parameters(), lr=0.0001)
epochs     = 50
train_loss = []
train_acc  = []
test_loss  = []
test_acc   = []

# %%
def fit(epoch, model, trainloader, testloader):
    correct      = 0
    total        = 0
    running_loss = 0
    
    model.train()
    for b in trainloader:
        x, y     = b.text, b.label
        if torch.cuda.is_available():
            x, y = x.to('cuda'), y.to('cuda')
        y_pred   = model(x)
        loss     = loss_fn(y_pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            y_pred        = torch.argmax(y_pred, dim=1)
            correct      += (y_pred == y).sum().item()
            total        += y.size(0)
            running_loss += loss.item()
    epoch_loss = running_loss / len(trainloader.dataset)
    epoch_acc  = correct / total
        
        
    test_correct      = 0
    test_total        = 0
    test_running_loss = 0 
    
    model.eval()
    with torch.no_grad():
        for b in testloader:
            x, y   = b.text, b.label
            if torch.cuda.is_available():
                x, y = x.to('cuda'), y.to('cuda')
            y_pred = model(x)
            loss   = loss_fn(y_pred, y)
            y_pred = torch.argmax(y_pred, dim=1)
            test_correct      += (y_pred == y).sum().item()
            test_total        += y.size(0)
            test_running_loss += loss.item()
    
    epoch_test_loss = test_running_loss / len(testloader.dataset)
    epoch_test_acc  = test_correct / test_total
    
        
    print('epoch: ', epoch,'loss： ', round(epoch_loss, 3),'accuracy:', round(epoch_acc, 3),'test_loss： ', round(epoch_test_loss, 3),'test_accuracy:', round(epoch_test_acc, 3))
        
    return epoch_loss, epoch_acc, epoch_test_loss, epoch_test_acc

# %%
for epoch in range(epochs):
    epoch_loss, epoch_acc, epoch_test_loss, epoch_test_acc = fit(epoch,model,train_iter,test_iter)
    train_loss.append(epoch_loss)
    train_acc.append(epoch_acc)
    test_loss.append(epoch_test_loss)
    test_acc.append(epoch_test_acc)
# Out:
# epoch:  0 loss：  0.003 accuracy: 0.507 test_loss：  0.003 test_accuracy: 0.504
# epoch:  0 loss：  0.003 accuracy: 0.507 test_loss：  0.003 test_accuracy: 0.504
# epoch:  1 loss：  0.003 accuracy: 0.508 test_loss：  0.003 test_accuracy: 0.508
# epoch:  1 loss：  0.003 accuracy: 0.508 test_loss：  0.003 test_accuracy: 0.508
# epoch:  2 loss：  0.003 accuracy: 0.512 test_loss：  0.003 test_accuracy: 0.503
# epoch:  2 loss：  0.003 accuracy: 0.512 test_loss：  0.003 test_accuracy: 0.503
# epoch:  3 loss：  0.003 accuracy: 0.521 test_loss：  0.003 test_accuracy: 0.512
# epoch:  3 loss：  0.003 accuracy: 0.521 test_loss：  0.003 test_accuracy: 0.512
# epoch:  4 loss：  0.003 accuracy: 0.525 test_loss：  0.003 test_accuracy: 0.516
# epoch:  4 loss：  0.003 accuracy: 0.525 test_loss：  0.003 test_accuracy: 0.516
# epoch:  5 loss：  0.003 accuracy: 0.527 test_loss：  0.003 test_accuracy: 0.508
# epoch:  5 loss：  0.003 accuracy: 0.527 test_loss：  0.003 test_accuracy: 0.508
# epoch:  6 loss：  0.003 accuracy: 0.535 test_loss：  0.003 test_accuracy: 0.546
# epoch:  6 loss：  0.003 accuracy: 0.535 test_loss：  0.003 test_accuracy: 0.546
# epoch:  7 loss：  0.003 accuracy: 0.547 test_loss：  0.003 test_accuracy: 0.542
# epoch:  7 loss：  0.003 accuracy: 0.547 test_loss：  0.003 test_accuracy: 0.542
# epoch:  8 loss：  0.003 accuracy: 0.611 test_loss：  0.002 test_accuracy: 0.638
# epoch:  8 loss：  0.003 accuracy: 0.611 test_loss：  0.002 test_accuracy: 0.638
# epoch:  9 loss：  0.002 accuracy: 0.678 test_loss：  0.002 test_accuracy: 0.688
# epoch:  9 loss：  0.002 accuracy: 0.678 test_loss：  0.002 test_accuracy: 0.688
# epoch:  10 loss：  0.002 accuracy: 0.699 test_loss：  0.002 test_accuracy: 0.708
# epoch:  10 loss：  0.002 accuracy: 0.699 test_loss：  0.002 test_accuracy: 0.708
# epoch:  11 loss：  0.002 accuracy: 0.726 test_loss：  0.002 test_accuracy: 0.667
# epoch:  11 loss：  0.002 accuracy: 0.726 test_loss：  0.002 test_accuracy: 0.667
# epoch:  12 loss：  0.002 accuracy: 0.739 test_loss：  0.002 test_accuracy: 0.732
# epoch:  12 loss：  0.002 accuracy: 0.739 test_loss：  0.002 test_accuracy: 0.732
# epoch:  13 loss：  0.002 accuracy: 0.758 test_loss：  0.002 test_accuracy: 0.739
# epoch:  13 loss：  0.002 accuracy: 0.758 test_loss：  0.002 test_accuracy: 0.739
# epoch:  14 loss：  0.002 accuracy: 0.766 test_loss：  0.002 test_accuracy: 0.741
# epoch:  14 loss：  0.002 accuracy: 0.766 test_loss：  0.002 test_accuracy: 0.741
# epoch:  15 loss：  0.002 accuracy: 0.777 test_loss：  0.002 test_accuracy: 0.761
# epoch:  15 loss：  0.002 accuracy: 0.777 test_loss：  0.002 test_accuracy: 0.761
# epoch:  16 loss：  0.002 accuracy: 0.782 test_loss：  0.002 test_accuracy: 0.758
# epoch:  16 loss：  0.002 accuracy: 0.782 test_loss：  0.002 test_accuracy: 0.758
# epoch:  17 loss：  0.002 accuracy: 0.793 test_loss：  0.002 test_accuracy: 0.77
# epoch:  17 loss：  0.002 accuracy: 0.793 test_loss：  0.002 test_accuracy: 0.77
# epoch:  18 loss：  0.002 accuracy: 0.802 test_loss：  0.002 test_accuracy: 0.776
# epoch:  18 loss：  0.002 accuracy: 0.802 test_loss：  0.002 test_accuracy: 0.776
# epoch:  19 loss：  0.002 accuracy: 0.81 test_loss：  0.002 test_accuracy: 0.782
# epoch:  19 loss：  0.002 accuracy: 0.81 test_loss：  0.002 test_accuracy: 0.782
# epoch:  20 loss：  0.002 accuracy: 0.816 test_loss：  0.002 test_accuracy: 0.772
# epoch:  20 loss：  0.002 accuracy: 0.816 test_loss：  0.002 test_accuracy: 0.772
# epoch:  21 loss：  0.002 accuracy: 0.822 test_loss：  0.002 test_accuracy: 0.789
# epoch:  21 loss：  0.002 accuracy: 0.822 test_loss：  0.002 test_accuracy: 0.789
# epoch:  22 loss：  0.002 accuracy: 0.825 test_loss：  0.002 test_accuracy: 0.794
# epoch:  22 loss：  0.002 accuracy: 0.825 test_loss：  0.002 test_accuracy: 0.794
# epoch:  23 loss：  0.001 accuracy: 0.832 test_loss：  0.002 test_accuracy: 0.793
# epoch:  23 loss：  0.001 accuracy: 0.832 test_loss：  0.002 test_accuracy: 0.793
# epoch:  24 loss：  0.001 accuracy: 0.838 test_loss：  0.002 test_accuracy: 0.801
# epoch:  24 loss：  0.001 accuracy: 0.838 test_loss：  0.002 test_accuracy: 0.801
# epoch:  25 loss：  0.001 accuracy: 0.834 test_loss：  0.002 test_accuracy: 0.795
# epoch:  25 loss：  0.001 accuracy: 0.834 test_loss：  0.002 test_accuracy: 0.795
# epoch:  26 loss：  0.001 accuracy: 0.848 test_loss：  0.002 test_accuracy: 0.804
# epoch:  26 loss：  0.001 accuracy: 0.848 test_loss：  0.002 test_accuracy: 0.804
# epoch:  27 loss：  0.001 accuracy: 0.851 test_loss：  0.002 test_accuracy: 0.806
# epoch:  27 loss：  0.001 accuracy: 0.851 test_loss：  0.002 test_accuracy: 0.806
# epoch:  28 loss：  0.001 accuracy: 0.855 test_loss：  0.002 test_accuracy: 0.799
# epoch:  28 loss：  0.001 accuracy: 0.855 test_loss：  0.002 test_accuracy: 0.799
# epoch:  29 loss：  0.001 accuracy: 0.856 test_loss：  0.002 test_accuracy: 0.807
# epoch:  29 loss：  0.001 accuracy: 0.856 test_loss：  0.002 test_accuracy: 0.807
# epoch:  30 loss：  0.001 accuracy: 0.862 test_loss：  0.002 test_accuracy: 0.807
# epoch:  30 loss：  0.001 accuracy: 0.862 test_loss：  0.002 test_accuracy: 0.807
# epoch:  31 loss：  0.001 accuracy: 0.864 test_loss：  0.002 test_accuracy: 0.805
# epoch:  31 loss：  0.001 accuracy: 0.864 test_loss：  0.002 test_accuracy: 0.805
# epoch:  32 loss：  0.001 accuracy: 0.865 test_loss：  0.002 test_accuracy: 0.798
# epoch:  32 loss：  0.001 accuracy: 0.865 test_loss：  0.002 test_accuracy: 0.798
# epoch:  33 loss：  0.001 accuracy: 0.87 test_loss：  0.002 test_accuracy: 0.816
# epoch:  33 loss：  0.001 accuracy: 0.87 test_loss：  0.002 test_accuracy: 0.816
# epoch:  34 loss：  0.001 accuracy: 0.876 test_loss：  0.002 test_accuracy: 0.814
# epoch:  34 loss：  0.001 accuracy: 0.876 test_loss：  0.002 test_accuracy: 0.814
# epoch:  35 loss：  0.001 accuracy: 0.877 test_loss：  0.002 test_accuracy: 0.819
# epoch:  35 loss：  0.001 accuracy: 0.877 test_loss：  0.002 test_accuracy: 0.819
# epoch:  36 loss：  0.001 accuracy: 0.879 test_loss：  0.002 test_accuracy: 0.819
# epoch:  36 loss：  0.001 accuracy: 0.879 test_loss：  0.002 test_accuracy: 0.819
# epoch:  37 loss：  0.001 accuracy: 0.884 test_loss：  0.002 test_accuracy: 0.82
# epoch:  37 loss：  0.001 accuracy: 0.884 test_loss：  0.002 test_accuracy: 0.82
# epoch:  38 loss：  0.001 accuracy: 0.887 test_loss：  0.002 test_accuracy: 0.821
# epoch:  38 loss：  0.001 accuracy: 0.887 test_loss：  0.002 test_accuracy: 0.821
# epoch:  39 loss：  0.001 accuracy: 0.889 test_loss：  0.002 test_accuracy: 0.817
# epoch:  39 loss：  0.001 accuracy: 0.889 test_loss：  0.002 test_accuracy: 0.817
# epoch:  40 loss：  0.001 accuracy: 0.892 test_loss：  0.002 test_accuracy: 0.824
# epoch:  40 loss：  0.001 accuracy: 0.892 test_loss：  0.002 test_accuracy: 0.824
# epoch:  41 loss：  0.001 accuracy: 0.899 test_loss：  0.002 test_accuracy: 0.817
# epoch:  41 loss：  0.001 accuracy: 0.899 test_loss：  0.002 test_accuracy: 0.817
# epoch:  42 loss：  0.001 accuracy: 0.894 test_loss：  0.002 test_accuracy: 0.826
# epoch:  42 loss：  0.001 accuracy: 0.894 test_loss：  0.002 test_accuracy: 0.826
# epoch:  43 loss：  0.001 accuracy: 0.903 test_loss：  0.002 test_accuracy: 0.822
# epoch:  43 loss：  0.001 accuracy: 0.903 test_loss：  0.002 test_accuracy: 0.822
# epoch:  44 loss：  0.001 accuracy: 0.905 test_loss：  0.002 test_accuracy: 0.827
# epoch:  44 loss：  0.001 accuracy: 0.905 test_loss：  0.002 test_accuracy: 0.827
# epoch:  45 loss：  0.001 accuracy: 0.906 test_loss：  0.002 test_accuracy: 0.824
# epoch:  45 loss：  0.001 accuracy: 0.906 test_loss：  0.002 test_accuracy: 0.824
# epoch:  46 loss：  0.001 accuracy: 0.914 test_loss：  0.002 test_accuracy: 0.825
# epoch:  46 loss：  0.001 accuracy: 0.914 test_loss：  0.002 test_accuracy: 0.825
# epoch:  47 loss：  0.001 accuracy: 0.91 test_loss：  0.002 test_accuracy: 0.825
# epoch:  47 loss：  0.001 accuracy: 0.91 test_loss：  0.002 test_accuracy: 0.825
# epoch:  48 loss：  0.001 accuracy: 0.917 test_loss：  0.002 test_accuracy: 0.827
# epoch:  48 loss：  0.001 accuracy: 0.917 test_loss：  0.002 test_accuracy: 0.827
# epoch:  49 loss：  0.001 accuracy: 0.921 test_loss：  0.002 test_accuracy: 0.823
# epoch:  49 loss：  0.001 accuracy: 0.921 test_loss：  0.002 test_accuracy: 0.823
